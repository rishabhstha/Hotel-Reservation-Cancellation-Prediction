# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import pyplot
import seaborn as sns

# %%
h1=pd.read_csv("H1.csv")

# %%
h1
# Out:
#        IsCanceled  LeadTime  ArrivalDateYear ArrivalDateMonth  \
# 0               0       342             2015             July
# 1               0       737             2015             July
# 2               0         7             2015             July
# 3               0        13             2015             July
# 4               0        14             2015             July
# ...           ...       ...              ...              ...
# 40055           0       212             2017           August
# 40056           0       169             2017           August
# 40057           0       204             2017           August
# 40058           0       211             2017           August
# 40059           0       161             2017           August
#
#        ArrivalDateWeekNumber  ArrivalDateDayOfMonth  StaysInWeekendNights  \
# 0                         27                      1                     0
# ...

# %%
h1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40060 entries, 0 to 40059
# Data columns (total 31 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   IsCanceled                   40060 non-null  int64
#  1   LeadTime                     40060 non-null  int64
#  2   ArrivalDateYear              40060 non-null  int64
#  3   ArrivalDateMonth             40060 non-null  object
#  4   ArrivalDateWeekNumber        40060 non-null  int64
#  5   ArrivalDateDayOfMonth        40060 non-null  int64
#  6   StaysInWeekendNights         40060 non-null  int64
#  7   StaysInWeekNights            40060 non-null  int64
#  8   Adults                       40060 non-null  int64
#  9   Children                     40060 non-null  int64
#  10  Babies                       40060 non-null  int64
#  11  Meal                         40060 non-null  object
#  12  Country                      39596 non-null  object
# ...

# %%
h1.isnull().sum()
# Out:
# IsCanceled                       0
# LeadTime                         0
# ArrivalDateYear                  0
# ArrivalDateMonth                 0
# ArrivalDateWeekNumber            0
# ArrivalDateDayOfMonth            0
# StaysInWeekendNights             0
# StaysInWeekNights                0
# Adults                           0
# Children                         0
# Babies                           0
# Meal                             0
# Country                        464
# MarketSegment                    0
# DistributionChannel              0
# IsRepeatedGuest                  0
# PreviousCancellations            0
# PreviousBookingsNotCanceled      0
# ReservedRoomType                 0
# AssignedRoomType                 0
# BookingChanges                   0
# DepositType                      0
# Agent                            0
# Company                          0
# DaysInWaitingList                0
# CustomerType                     0
# ADR                              0
# ...

# %%
h1['Country']
# Out:
# 0        PRT
# 1        PRT
# 2        GBR
# 3        GBR
# 4        GBR
#         ...
# 40055    GBR
# 40056    IRL
# 40057    IRL
# 40058    GBR
# 40059    DEU
# Name: Country, Length: 40060, dtype: object

# %%
h1.describe()
# Out:
#          IsCanceled      LeadTime  ArrivalDateYear  ArrivalDateWeekNumber  \
# count  40060.000000  40060.000000     40060.000000           40060.000000
# mean       0.277634     92.675686      2016.121443              27.140864
# std        0.447837     97.285315         0.722347              14.005441
# min        0.000000      0.000000      2015.000000               1.000000
# 25%        0.000000     10.000000      2016.000000              16.000000
# 50%        0.000000     57.000000      2016.000000              28.000000
# 75%        1.000000    155.000000      2017.000000              38.000000
# max        1.000000    737.000000      2017.000000              53.000000
#
#        ArrivalDateDayOfMonth  StaysInWeekendNights  StaysInWeekNights  \
# count           40060.000000          40060.000000       40060.000000
# mean               15.821243              1.189815           3.128732
# std                 8.883708              1.147812           2.461329
# ...

# %%
h1['IsCanceled'].value_counts()
# Out:
# 0    28938
# 1    11122
# Name: IsCanceled, dtype: int64

# %%
sns.countplot(x='IsCanceled',data=h1)
# Out:
# <AxesSubplot:xlabel='IsCanceled', ylabel='count'>

# %%
# cancellations by repeated guests - repeated guests do not cancel their reservations.
sns.set(style = "darkgrid")
plt.title("Repeated Guests Cancellations")
ax = sns.countplot(x = "IsCanceled", hue = 'IsRepeatedGuest', data = h1)

# %%
plt.figure(figsize = (13,10))
sns.set(style = "darkgrid")
plt.title("Countplot Distributon of Segments by Cancellation")
ax = sns.countplot(x = "MarketSegment", hue = 'IsCanceled', data = h1)

# %%
#Cancellation by Month Types
plt.figure(figsize =(11,8))
#sns.set(style="darkgrid")
plt.title("Customers by month ", fontdict={'fontsize': 16})
ax = sns.countplot(x = "ArrivalDateMonth", data = h1, order=pd.value_counts(h1['ArrivalDateMonth']).index)

# %%
h1_canceled=h1.loc[h1['IsCanceled']==1]

plt.figure(figsize =(11,8))
plt.title("Cancellations by month ", fontdict={'fontsize': 16})
ax = sns.countplot(x = "ArrivalDateMonth", data = h1_canceled, order=pd.value_counts(h1_canceled['ArrivalDateMonth']).index)

# %%
h1= h1.dropna()
h1.isnull().sum()
# Out:
# IsCanceled                     0
# LeadTime                       0
# ArrivalDateYear                0
# ArrivalDateMonth               0
# ArrivalDateWeekNumber          0
# ArrivalDateDayOfMonth          0
# StaysInWeekendNights           0
# StaysInWeekNights              0
# Adults                         0
# Children                       0
# Babies                         0
# Meal                           0
# Country                        0
# MarketSegment                  0
# DistributionChannel            0
# IsRepeatedGuest                0
# PreviousCancellations          0
# PreviousBookingsNotCanceled    0
# ReservedRoomType               0
# AssignedRoomType               0
# BookingChanges                 0
# DepositType                    0
# Agent                          0
# Company                        0
# DaysInWaitingList              0
# CustomerType                   0
# ADR                            0
# RequiredCarParkingSpaces       0
# ...

# %%
h1
# Out:
#        IsCanceled  LeadTime  ArrivalDateYear ArrivalDateMonth  \
# 0               0       342             2015             July
# 1               0       737             2015             July
# 2               0         7             2015             July
# 3               0        13             2015             July
# 4               0        14             2015             July
# ...           ...       ...              ...              ...
# 40055           0       212             2017           August
# 40056           0       169             2017           August
# 40057           0       204             2017           August
# 40058           0       211             2017           August
# 40059           0       161             2017           August
#
#        ArrivalDateWeekNumber  ArrivalDateDayOfMonth  StaysInWeekendNights  \
# 0                         27                      1                     0
# ...

# %%
h1['Company'].value_counts()
h1['Agent'].value_counts()
# Out:
#         240    13854
#        NULL     7883
#         250     2854
#         241     1718
#          40     1002
#                ...
#          34        1
#         337        1
#         193        1
#         187        1
#         406        1
# Name: Agent, Length: 185, dtype: int64

# %%
h1.loc[h1['Company'] == 'NULL']
# Out:
# Empty DataFrame
# Columns: [IsCanceled, LeadTime, ArrivalDateYear, ArrivalDateMonth, ArrivalDateWeekNumber, ArrivalDateDayOfMonth, StaysInWeekendNights, StaysInWeekNights, Adults, Children, Babies, Meal, Country, MarketSegment, DistributionChannel, IsRepeatedGuest, PreviousCancellations, PreviousBookingsNotCanceled, ReservedRoomType, AssignedRoomType, BookingChanges, DepositType, Agent, Company, DaysInWaitingList, CustomerType, ADR, RequiredCarParkingSpaces, TotalOfSpecialRequests, ReservationStatus, ReservationStatusDate]
# Index: []
#
# [0 rows x 31 columns]

# %%
#barchart for counts of customer type
plt.figure(figsize=(18,6))
sns.countplot(x='CustomerType', data= h1)
plt.title('Customer Type')
plt.show()

# %%
#graphs for cancellations according to room type
plt.figure(figsize=(10,5))
sns.countplot(x=h1["AssignedRoomType"], hue=h1["IsCanceled"])
plt.title("Cancellations According to Room Type")
plt.legend(["NotCanceled", "Canceled"])
plt.tight_layout()
plt.show()

# %%
h1
# Out:
#        IsCanceled  LeadTime  ArrivalDateYear ArrivalDateMonth  \
# 0               0       342             2015             July
# 1               0       737             2015             July
# 2               0         7             2015             July
# 3               0        13             2015             July
# 4               0        14             2015             July
# ...           ...       ...              ...              ...
# 40055           0       212             2017           August
# 40056           0       169             2017           August
# 40057           0       204             2017           August
# 40058           0       211             2017           August
# 40059           0       161             2017           August
#
#        ArrivalDateWeekNumber  ArrivalDateDayOfMonth  StaysInWeekendNights  \
# 0                         27                      1                     0
# ...

# %%
#Preprocessing of data

h1_drop=h1.drop('Company',axis=1)
h1_drop=h1_drop.drop('Agent',axis=1)
h1_drop=h1_drop.drop('ReservationStatus',axis=1)

# %%
h1_drop
# Out:
#        IsCanceled  LeadTime  ArrivalDateYear ArrivalDateMonth  \
# 0               0       342             2015             July
# 1               0       737             2015             July
# 2               0         7             2015             July
# 3               0        13             2015             July
# 4               0        14             2015             July
# ...           ...       ...              ...              ...
# 40055           0       212             2017           August
# 40056           0       169             2017           August
# 40057           0       204             2017           August
# 40058           0       211             2017           August
# 40059           0       161             2017           August
#
#        ArrivalDateWeekNumber  ArrivalDateDayOfMonth  StaysInWeekendNights  \
# 0                         27                      1                     0
# ...

# %%
#Encoding Data
from sklearn.preprocessing import LabelEncoder

le=LabelEncoder()
h1['ArrivalDateMonth']=le.fit_transform(h1['ArrivalDateMonth'])

# %%
h1.head()
# Out:
#    IsCanceled  LeadTime  ArrivalDateYear  ArrivalDateMonth  \
# 0           0       342             2015                 5
# 1           0       737             2015                 5
# 2           0         7             2015                 5
# 3           0        13             2015                 5
# 4           0        14             2015                 5
#
#    ArrivalDateWeekNumber  ArrivalDateDayOfMonth  StaysInWeekendNights  \
# 0                     27                      1                     0
# 1                     27                      1                     0
# 2                     27                      1                     0
# 3                     27                      1                     0
# 4                     27                      1                     0
#
#    StaysInWeekNights  Adults  Children  ...  BookingChanges      DepositType  \
# 0                  0       2         0  ...               3  No Deposit
# ...

# %%
h1_canceled=h1.loc[h1['IsCanceled']==1]
h1_canceled_bydate=h1_canceled.groupby('ReservationStatusDate').sum()
#h1_canceled_bydate=h1_canceled_bydate.reset_index()


h1_canceled_bydate['IsCanceled'].unique()
#h1_canceled_bydate.plot.bar(y='IsCanceled')

h1_canceled_bydate


h1_canceled_bydate_g50=h1_canceled_bydate.loc[h1_canceled_bydate['IsCanceled']> 50].sort_values('IsCanceled')

# %%
h1_canceled_bydate_g50.plot.bar(y='IsCanceled')
plt.title("Top dates with highest cancellations")
# Out:
# Text(0.5, 1.0, 'Top dates with highest cancellations')

# %%
df_one_hot_encoder = pd.get_dummies(data=h1_drop, columns=['ArrivalDateMonth','Meal',
                                                'Country',
                                                 'MarketSegment',
                                                 'DistributionChannel',
                                                'ReservedRoomType',
                                                 'AssignedRoomType',
                                                'DepositType',
                                                'CustomerType',
                                                 'ReservationStatusDate'])

# %%
df_one_hot_encoder
# Out:
#        IsCanceled  LeadTime  ArrivalDateYear  ArrivalDateWeekNumber  \
# 0               0       342             2015                     27
# 1               0       737             2015                     27
# 2               0         7             2015                     27
# 3               0        13             2015                     27
# 4               0        14             2015                     27
# ...           ...       ...              ...                    ...
# 40055           0       212             2017                     35
# 40056           0       169             2017                     35
# 40057           0       204             2017                     35
# 40058           0       211             2017                     35
# 40059           0       161             2017                     35
#
#        ArrivalDateDayOfMonth  StaysInWeekendNights  StaysInWeekNights  Adults  \
# ...

# %%
X_hot = df_one_hot_encoder.drop('IsCanceled',axis=1)
#X_hot=X_hot.drop('Meal',axis=1)
y_hot = df_one_hot_encoder['IsCanceled']

# %%
#for one hot encoding- dropping reservationstatus, company, agent using RandomForest
from sklearn.model_selection import train_test_split

X_train_hot, X_test_hot, y_train_hot, y_test_hot = train_test_split(
    X_hot, y_hot, test_size=0.2, random_state=42)

from sklearn.ensemble import RandomForestClassifier
model_hot = RandomForestClassifier(n_estimators=400)
model_hot.fit(X_train_hot,y_train_hot)
y_pred_hot = model_hot.predict(X_test_hot)

from sklearn.metrics import accuracy_score,confusion_matrix
accuracy_score(y_test_hot,y_pred_hot)
# Out:
# 0.9142676767676767

# %%
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score,roc_auc_score, plot_confusion_matrix,plot_roc_curve
print(classification_report(y_test_hot,y_pred_hot))
print('Confusion matrix : \n{}'.format(confusion_matrix(y_test_hot,y_pred_hot)))
print(accuracy_score(y_test_hot,y_pred_hot))

plot_confusion_matrix(model_hot, X_test_hot, y_test_hot,cmap=plt.cm.Blues)
plot_roc_curve(model_hot, X_test_hot, y_test_hot)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.97      0.94      5742
#            1       0.90      0.77      0.83      2178
#
#     accuracy                           0.91      7920
#    macro avg       0.91      0.87      0.89      7920
# weighted avg       0.91      0.91      0.91      7920
#
# Confusion matrix :
# [[5562  180]
#  [ 499 1679]]
# 0.9142676767676767

# %%
#grid search cv for random forest
from sklearn.model_selection import GridSearchCV

rfc=RandomForestClassifier(random_state=42)
param_grid = { 
    'n_estimators': [200,400, 500],
    'max_features': ['auto', 'sqrt', 'log2'],
    'max_depth' : [4,5,6,7,8],
    'criterion' :['gini', 'entropy']
}
scores=['precision','recall']
for score in scores:
    
    print("# Tuning hyper-parameters for %s" % score)
    print()
    
    clf=GridSearchCV(estimator=rfc, param_grid=param_grid, scoring='%s_macro' % score, cv=3 )
    clf.fit(X_train_hot, y_train_hot)
    
    print("Best parameters set found on development set:")
    print()
    print(clf.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf.cv_results_['mean_test_score']
    stds = clf.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    y_true, y_pred = y_test_hot, clf.predict(X_test_hot)
    print(classification_report(y_true, y_pred))
    print()
# Out:
# # Tuning hyper-parameters for precision
# C:\Users\rishabhstha\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\rishabhstha\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
#Using Label Encoder
df_label_encoder=h1.copy()

# %%
def label_encoded(x):
    le=LabelEncoder()
    le.fit(x)
    return le.transform(x)

for col in df_label_encoder.columns:
    if isinstance(df_label_encoder[str(col)],object):
        df_label_encoder[str(col)] = label_encoded(h1[str(col)])
        
df_label_encoder
# Out:
#        IsCanceled  LeadTime  ArrivalDateYear  ArrivalDateMonth  \
# 0               0       342                0                 5
# 1               0       411                0                 5
# 2               0         7                0                 5
# 3               0        13                0                 5
# 4               0        14                0                 5
# ...           ...       ...              ...               ...
# 40055           0       212                2                 1
# 40056           0       169                2                 1
# 40057           0       204                2                 1
# 40058           0       211                2                 1
# 40059           0       161                2                 1
#
#        ArrivalDateWeekNumber  ArrivalDateDayOfMonth  StaysInWeekendNights  \
# 0                         26                      0                     0
# ...

# %%
plt.figure(figsize=(20,15))
sns.heatmap(df_label_encoder.corr(),annot=True,cmap='coolwarm')
plt.tight_layout
# Out:
# <function matplotlib.pyplot.tight_layout(*, pad=1.08, h_pad=None, w_pad=None, rect=None)>

# %%
hotel_new=h1[['IsCanceled','LeadTime','StaysInWeekendNights','StaysInWeekNights','Adults','Children','Country','MarketSegment','DistributionChannel','IsRepeatedGuest','PreviousCancellations','AssignedRoomType','BookingChanges','DepositType','ADR','RequiredCarParkingSpaces','TotalOfSpecialRequests','ReservationStatusDate']].copy()

# %%
hotel_new
# Out:
#        IsCanceled  LeadTime  StaysInWeekendNights  StaysInWeekNights  Adults  \
# 0               0       342                     0                  0       2
# 1               0       737                     0                  0       2
# 2               0         7                     0                  1       1
# 3               0        13                     0                  1       1
# 4               0        14                     0                  2       2
# ...           ...       ...                   ...                ...     ...
# 40055           0       212                     2                  8       2
# 40056           0       169                     2                  9       2
# 40057           0       204                     4                 10       2
# 40058           0       211                     4                 10       2
# 40059           0       161                     4                 10       2
#
# ...

# %%
        
hotel_new['Country']=label_encoded(hotel_new['Country'])
hotel_new
# Out:
#        IsCanceled  LeadTime  StaysInWeekendNights  StaysInWeekNights  Adults  \
# 0               0       342                     0                  0       2
# 1               0       737                     0                  0       2
# 2               0         7                     0                  1       1
# 3               0        13                     0                  1       1
# 4               0        14                     0                  2       2
# ...           ...       ...                   ...                ...     ...
# 40055           0       212                     2                  8       2
# 40056           0       169                     2                  9       2
# 40057           0       204                     4                 10       2
# 40058           0       211                     4                 10       2
# 40059           0       161                     4                 10       2
#
# ...

# %%
# hotel_new=hotel_new.drop('ArrivalDateYear',axis=1)
# hotel_new=hotel_new.drop('ArrivalDateMonth', axis=1)
# hotel_new=hotel_new.drop('ArrivalDateWeekNumber',axis=1)
# hotel_new=hotel_new.drop('ArrivalDateDayOfMonth',axis=1)
# hotel_new=hotel_new.drop('Babies',axis=1)
# hotel_new=hotel_new.drop('Meal',axis=1)
# hotel_new=hotel_new.drop('PreviousBookingsNotCanceled',axis=1)
# hotel_new=hotel_new.drop('ReservedRoomType',axis=1)
# hotel_new=hotel_new.drop('Agent',axis=1)

# %%
X_LE = df_label_encoder.drop('IsCanceled',axis=1)
y_LE = df_label_encoder['IsCanceled']

# %%
X_LE=X_LE.drop('ReservationStatus',axis=1)

# %%
from sklearn.model_selection import train_test_split

X_train_LE, X_test_LE, y_train_LE, y_test_LE = train_test_split(
    X_LE, y_LE, test_size=0.2, random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier
model_LE = RandomForestClassifier(n_estimators=400)
model_LE.fit(X_train_LE,y_train_LE)
y_pred_LE = model_LE.predict(X_test_LE)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix

print(accuracy_score(y_test_LE,y_pred_LE))
confusion_matrix(y_test_LE,y_pred_LE)
print(classification_report(y_test_LE,y_pred_LE))
# Out:
# 0.9460858585858586
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.96      5742
#            1       0.94      0.86      0.90      2178
#
#     accuracy                           0.95      7920
#    macro avg       0.94      0.92      0.93      7920
# weighted avg       0.95      0.95      0.95      7920

# %%
df_label_encoder['ArrivalDateMonth'].unique()
df_label_encoder['ReservationStatus'].unique()
df_label_encoder['CustomerType'].unique()
df_label_encoder['DaysInWaitingList'].unique()
df_label_encoder['Company'].unique()
# Out:
# array([232,  44,  46,  89,  64,  79,  57,  54, 104,  87,  22,  71, 106,
#        108,  37,  63,  91,  68,  75, 107,  94,  48,  20,  96,   3,  17,
#        111, 119, 140, 138,  34,  31,  74,  35,  10, 155, 151, 162, 115,
#        135,   6,  32, 169,  18, 153,  39,  12,  33, 129, 152, 146, 193,
#        198,  45, 202, 171,   1, 105,  52,  76, 211,  88, 127, 208, 149,
#        216,  70,  86, 197, 222,  62, 218, 184, 117,  83, 176, 101, 148,
#         51,  82, 126,  84, 231, 227, 225,  49,  30,  47, 226,  40,  24,
#         13,   5,  23,  36, 210, 100,  99,  66,  16, 194,  97, 102,  72,
#        179,  59, 113,  90,   8,  27, 199,  69,  15, 118,  42,  26,  81,
#        109,  55,  58, 145, 110, 214, 163, 112,  93,  29, 161, 157,   4,
#         53, 120, 121, 122, 123,  98, 124, 125,  21,  38, 128, 130, 131,
#        134, 139, 133,  92,  43, 142, 144,   7, 143, 114, 132, 159,  78,
#         85, 147,  60,  73, 217, 150, 158, 141, 160, 154, 103, 156,  77,
# ...

# %%
h1['ReservationStatus'].unique()
h1['CustomerType'].unique()
h1['DaysInWaitingList'].unique()
h1['Company'].unique()
h1['Country'].unique()
h1['Meal'].unique()
# Out:
# array(['BB       ', 'FB       ', 'HB       ', 'SC       ', 'Undefined'],
#       dtype=object)
